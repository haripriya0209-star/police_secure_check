# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
df = pd.read_csv(r"D:\Secure check project\traffic_stops - traffic_stops_with_vehicle_number.csv", low_memory=False)

# %% [markdown]
# # Drop columns with all missing values

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.head(10)
# Out:
#     stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0  2020-01-01   0:00:00       Canada             M              59
# 1  2020-01-01   0:01:00        India             M              35
# 2  2020-01-01   0:02:00          USA             M              26
# 3  2020-01-01   0:03:00       Canada             M              26
# 4  2020-01-01   0:04:00       Canada             M              62
# 5  2020-01-01   0:05:00       Canada             F              44
# 6  2020-01-01   0:06:00          USA             F              80
# 7  2020-01-01   0:07:00        India             M              72
# 8  2020-01-01   0:08:00          USA             F              80
# 9  2020-01-01   0:09:00          USA             M              43
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0          19       Asian     Drunk Driving  Speeding              True
# 1          58       Other             Other     Other             False
# ...

# %%
df.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %% [markdown]
# Fill missing Values --- Handle NaN values

# %%
df.loc [(df['search_type'].isnull()), 'search_type'] = 'No Search'

# %% [markdown]
# DROP SPECFIC COLUMNS

# %%
df.drop(['violation_raw','driver_age_raw'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender', 'driver_age',
#        'driver_race', 'violation', 'search_conducted', 'search_type',
#        'stop_outcome', 'is_arrested', 'stop_duration', 'drugs_related_stop',
#        'vehicle_number'],
#       dtype='object')

# %% [markdown]
# save the cleaned data

# %%
df.to_csv(r"D:\Secure check project\cleaned_traffic_stop.csv",index=False) #Tells pandas not to include the row index in the CSV file (just the data columns).

# %%
df.dtypes
# Out:
# stop_date             object
# stop_time             object
# country_name          object
# driver_gender         object
# driver_age             int64
# driver_race           object
# violation             object
# search_conducted        bool
# search_type           object
# stop_outcome          object
# is_arrested             bool
# stop_duration         object
# drugs_related_stop      bool
# vehicle_number        object
# dtype: object

# %% [markdown]
# convert to date - time format for stop_date and stop_time column

# %%
#df['stop_date']=pd.to_datetime(df['stop_date'])
#df['stop_time'] = pd.to_datetime(df['stop_time'], format='%H:%M:%S', errors='coerce').dt.time

# %% [markdown]
# So i have to convert the datetime back to object for combining both the coloumns

# %%
df['stop_date'] = pd.to_datetime(df['stop_date']).dt.date

# %% [markdown]
# Combining to col to convert to date time data type from object

# %%
import pandas as pd

df['stop_time'] = pd.to_datetime(df['stop_time'], format='%H:%M:%S', errors='coerce').dt.time
df['timestamp'] = df.apply(lambda row: pd.Timestamp.combine(row['stop_date'], row['stop_time']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 import pandas as pd
# ----> 3 df['timestamp'] = df.apply(lambda row: pd.Timestamp.combine(row['stop_date'], row['stop_time']), axis=1)
#
# File c:\Users\harip\anaconda3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\harip\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# ...

# %%
df.dtypes
# Out:
# stop_date                     object
# stop_time                     object
# country_name                  object
# driver_gender                 object
# driver_age                     int64
# driver_race                   object
# violation                     object
# search_conducted                bool
# search_type                   object
# stop_outcome                  object
# is_arrested                     bool
# stop_duration                 object
# drugs_related_stop              bool
# vehicle_number                object
# timestamp             datetime64[ns]
# dtype: object

# %% [markdown]
# LOADING THE CLEANED DATA

# %%
df = pd.read_csv(r'D:\Traffic police project\cleaned_traffic_stop.csv',low_memory=False)

# %%
df.head(5)
# Out:
#     stop_date stop_time country_name driver_gender  driver_age driver_race  \
# 0  2020-01-01  00:00:00       Canada             M          19       Asian
# 1  2020-01-01  00:01:00        India             M          58       Other
# 2  2020-01-01  00:02:00          USA             M          76       Black
# 3  2020-01-01  00:03:00       Canada             M          76       Black
# 4  2020-01-01  00:04:00       Canada             M          75       Other
#
#   violation  search_conducted     search_type stop_outcome  is_arrested  \
# 0  Speeding              True  Vehicle Search       Ticket         True
# 1     Other             False  Vehicle Search       Arrest         True
# 2  Speeding             False           Frisk       Ticket         True
# 3       DUI              True           Frisk      Warning        False
# 4     Other             False  Vehicle Search       Arrest         True
#
#   stop_duration  drugs_related_stop vehicle_number            timestamp
# ...

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender', 'driver_age',
#        'driver_race', 'violation', 'search_conducted', 'search_type',
#        'stop_outcome', 'is_arrested', 'stop_duration', 'drugs_related_stop',
#        'vehicle_number', 'timestamp'],
#       dtype='object')

# %% [markdown]
# Connecting Mysql Database

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",       # or your server IP
    user="root",            # your MySQL username
    password="1994",        # your MySQL password
  
)

# Create a cursor
cursor_mysql= conn.cursor()

# Create database
cursor_mysql.execute("CREATE DATABASE IF NOT EXISTS Secure_check;")
print("MySQL database 'Secure_check' created successfully!")
# Out:
# MySQL database 'Secure_check' created successfully!

# %% [markdown]
# Table creation

# %%
cursor_mysql.execute("USE Secure_check;")
cursor_mysql.execute("""
        create table if not exists traffic_stops  (
                     stop_date DATE NOT NULL,
                     stop_time DATE NOT NULL,
                     country_name VARCHAR(50),
                     driver_gender VARCHAR(10),
                     driver_age INT,
                     driver_race VARCHAR(50),
                     violation VARCHAR(100),
                     search_conducted BOOLEAN,
                     search_type VARCHAR(100),
                     stop_outcome VARCHAR(100),
                     is_arrested BOOLEAN,
                     stop_duration VARCHAR(20),
                     drugs_related_stop BOOLEAN,
                     vehicle_number VARCHAR(15)
                     ); 
                     """)

# %% [markdown]
# ADDING THE NEW CREATED COLOUMN TIMESTAMP INTO THE TABLE

# %%
cursor_mysql.execute("ALTER TABLE traffic_stops ADD COLUMN timestamp DATETIME;")

# %%
print(df['timestamp'].head())
# Out:
# 0   2020-01-01 00:00:00
# 1   2020-01-01 00:01:00
# 2   2020-01-01 00:02:00
# 3   2020-01-01 00:03:00
# 4   2020-01-01 00:04:00
# Name: timestamp, dtype: datetime64[ns]

# %% [markdown]
# converted timestamp col to datetime datatype

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
cursor_mysql.execute("ALTER TABLE traffic_stops MODIFY COLUMN stop_time TIME;")
conn.commit()

# %%
print(df.columns.tolist())
# Out:
# ['stop_date', 'stop_time', 'country_name', 'driver_gender', 'driver_age', 'driver_race', 'violation', 'search_conducted', 'search_type', 'stop_outcome', 'is_arrested', 'stop_duration', 'drugs_related_stop', 'vehicle_number', 'timestamp']

# %% [markdown]
# Insert data into the table

# %%
insert_query = """
    INSERT INTO traffic_stops (
        stop_date, stop_time, country_name, driver_gender, driver_age,
        driver_race, violation, search_conducted, search_type,
        stop_outcome, is_arrested, stop_duration, drugs_related_stop,
        vehicle_number, timestamp
    ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

data = [tuple(row) for row in df.to_numpy()]

cursor_mysql.executemany(insert_query, data)
conn.commit()
